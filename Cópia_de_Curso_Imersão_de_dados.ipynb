# %% [markdown]
# <a href="https://colab.research.google.com/github/Palheiros/Imersao_dados_Alura/blob/main/C%C3%B3pia_de_Curso_Imers%C3%A3o_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 01 - Dados da educação

# %%
import pandas as pd

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

dados = pd.read_csv(fonte)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
# Mostra o número de linhas x colunas da amostra

dados.shape
# Out:
# (127380, 136)

# %%
dados["SG_UF_RESIDENCIA"]
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
# Mostra os conteúdos únicos da coluna "SG_UF_RESIDENCIA"

dados["SG_UF_RESIDENCIA"].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
# Faz a contagem dos conteúdos únicos

len(dados["SG_UF_RESIDENCIA"].unique())
# Out:
# 27

# %%
dados["SG_UF_RESIDENCIA"].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados["NU_IDADE"].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
# sort_index() - coloca os dados da coluna escolhida em ordem crescente

dados["NU_IDADE"].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados["NU_IDADE"].hist()

# %%
# "bins" divide o range por um número de blocos no gráfico - no caso range / 20

dados["NU_IDADE"].hist(bins = 20)

# %%
dados["NU_IDADE"].hist(bins=20, figsize=(10,8))

# %%
# Faz uma query para mostrar a quantidade de inscritos que são treineiros (fazendo a prova como teste)

dados.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts()
# Out:
# 16    7142
# 17    4901
# 15    1927
# 18     858
# 19     228
# 20      83
# 14      64
# 21      44
# 22      30
# 23      21
# 24      13
# 26      13
# 29      10
# 27       9
# 25       8
# 28       6
# 38       4
# 40       4
# 31       4
# 30       4
# 42       4
# 34       3
# 36       2
# 39       2
# 32       2
# 46       2
# 44       2
# 35       2
# 45       1
# 41       1
# 33       1
# 62       1
# 48       1
# 51       1
# 37       1
# 47       1
# 55       1
# Name: NU_IDADE, dtype: int64

# %%
dados.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
dados["NU_NOTA_REDACAO"].hist(bins=20, figsize=(8,6))

# %%
# mean() - retorna a média dos dados (no caso a média das notas de redação)

dados["NU_NOTA_REDACAO"].mean()
# Out:
# 571.5700253970197

# %%
# .std - desvio padrão

dados["NU_NOTA_REDACAO"].std()
# Out:
# 188.07645455749753

# %%
provas = ["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_REDACAO"]

dados[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000

# %%
# quantile() - retornou que 10% dos alunos tiraram uma nota mais alta que 596.3 nessa disciplina

dados["NU_NOTA_LC"].quantile(0.9)
# Out:
# 596.3

# %%
dados["NU_NOTA_LC"].plot.box(grid = True, figsize=(8,6))

# %%
dados[provas].boxplot(grid=True, figsize= (10,8))

# %% [markdown]
# # Desafios da aula 01

# %% [markdown]
# Desafio 1 - Proporção dos inscritos por idade

# %%
dados['NU_IDADE'].value_counts(normalize=True)
# Out:
# 18    0.168409
# 17    0.166871
# 19    0.113189
# 20    0.081748
# 16    0.061470
#         ...
# 75    0.000016
# 73    0.000016
# 82    0.000008
# 77    0.000008
# 76    0.000008
# Name: NU_IDADE, Length: 65, dtype: float64

# %% [markdown]
# Desafio 2 - Descobrir de quais Estados são os inscritos com 13 anos

# %%
dados.query("NU_IDADE == 13")['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['SP', 'MT', 'AP', 'BA'], dtype=object)

# %% [markdown]
# Desafio 3 - Adicionar título no gráfico

# %%
import matplotlib.pyplot as plt

dados['NU_NOTA_REDACAO'].plot.hist(bins=20, figsize=(8, 6), title="Distribuição das notas de redação", grid=True)

# %% [markdown]
# Desafio 4 - Plotar os Histogramas das idades dos treineiros e não treineiros

# %%
dados_nao_treineiros = dados.query("IN_TREINEIRO == 0")
dados_nao_treineiros['NU_IDADE'].hist(bins=20, figsize=(8, 6))

dados_sim_treineiros = dados.query("IN_TREINEIRO == 1")
dados_sim_treineiros['NU_IDADE'].hist(bins=10, figsize=(8, 6))

# %% [markdown]
# Desafio 5 - Comparar as distribuições das provas em inglês e espanhol

# %%
dados_ingles = dados.query("TP_LINGUA == 0")['NU_NOTA_LC']
dados_ingles.plot.box(grid=True, figsize=(8, 6))
_ = plt.title("Grafico de caixa das notas de linguagem e códigos para quem escolheu inglês")

# %%
dados_espanhol = dados.query("TP_LINGUA == 1")['NU_NOTA_LC']
dados_espanhol.plot.box(grid=True, figsize=(8, 6))
_ = plt.title("Grafico de caixa das notas de linguagem e códigos para quem escolheu espanhol")

# %% [markdown]
# Desafio 6 - Explorar a documentações e visualizações com matplotlib ou pandas e gerar novas visualizações

# %%
idiomas = ['Espanhol','Ingles']
dados_por_idioma = pd.concat([dados_espanhol, dados_ingles], axis=1, names = idiomas)
dados_por_idioma.columns = idiomas
dados_por_idioma.plot.box(grid=True, figsize=(8, 6))
_ = plt.title("Grafico de caixa das notas de linguagem e códigos separado entre inglês e espanhol")

# %% [markdown]
# # Aula 02 - Análise exploratória

# %%
dados.query("NU_IDADE == 13")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 57359   190003297248    2019                  3504107  ...    B     B    B
# 95630   190004825557    2019                  5107602  ...    A     A    B
# 98197   190004926952    2019                  1600303  ...    A     B    B
# 116501  190005659236    2019                  2917508  ...    B     C    B
#
# [4 rows x 136 columns]

# %%
dados.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts()
# Out:
# PE    18
# CE    15
# BA    14
# PA    12
# SP    11
# MG    11
# MA     9
# PI     7
# GO     7
# PB     7
# AM     4
# DF     4
# MT     4
# PR     3
# TO     3
# SE     3
# RO     2
# AL     2
# SC     2
# AC     1
# RJ     1
# RS     1
# RN     1
# ES     1
# AP     1
# MS     1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
# normalize=True nos mostra a proporção entre 0 e 1 (pode ser lido como porcentagem)

dados.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts(normalize=True)
# Out:
# PE    0.124138
# CE    0.103448
# BA    0.096552
# PA    0.082759
# SP    0.075862
# MG    0.075862
# MA    0.062069
# PI    0.048276
# GO    0.048276
# PB    0.048276
# AM    0.027586
# DF    0.027586
# MT    0.027586
# PR    0.020690
# TO    0.020690
# SE    0.020690
# RO    0.013793
# AL    0.013793
# SC    0.013793
# AC    0.006897
# RJ    0.006897
# RS    0.006897
# RN    0.006897
# ES    0.006897
# AP    0.006897
# MS    0.006897
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
alunos_menor14 = dados.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts()
alunos_menor14.plot.pie(figsize=(10,8))

# %%
alunos_menor14.plot.bar(figsize=(10,8))

# %%
dados.query("NU_IDADE < 18")["SG_UF_RESIDENCIA"].value_counts()
# Out:
# SP    7321
# MG    3146
# BA    1993
# CE    1953
# PE    1805
# PR    1764
# RJ    1651
# PA    1268
# GO    1199
# MA    1164
# RS     990
# PB     838
# SC     795
# PI     678
# MT     612
# ES     517
# DF     472
# AL     446
# RN     429
# AM     428
# MS     421
# SE     405
# TO     344
# RO     234
# AP     188
# AC     109
# RR      70
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

renda_ordenada = dados["Q006"].unique()
renda_ordenada.sort()

plt.figure(figsize=(9,7))
sns.boxplot(x="Q006", y="NU_NOTA_MT", data = dados, order = renda_ordenada)
plt.title("Boxplot das notas de matemática pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matemática pela renda')

# %%
# Soma das notas por coluna (disciplina)

dados[provas].sum()
# Out:
# NU_NOTA_CN         44334986.1
# NU_NOTA_CH         49743676.1
# NU_NOTA_MT         48563933.8
# NU_NOTA_LC         51027844.9
# NU_NOTA_REDACAO    56038440.0
# dtype: float64

# %%
# Soma das notas por inscrito

dados[provas].sum(axis=1)
# Out:
# 0         2288.9
# 1         1184.6
# 2         2350.5
# 3         2555.7
# 4         2803.5
#            ...
# 127375    2867.4
# 127376    2218.5
# 127377    1453.9
# 127378    2573.9
# 127379    2287.8
# Length: 127380, dtype: float64

# %%
# Cria uma coluna com a soma das notas por inscrito (última coluna)

dados["NU_NOTA_TOTAL"] = dados[provas].sum(axis=1)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
# Boxplot com o somatório das notas

plt.figure(figsize=(9,7))
sns.boxplot(x="Q006", y="NU_NOTA_TOTAL", data = dados, order = renda_ordenada)
plt.title("Boxplot do somatório das notas pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot do somatório das notas pela renda')

# %%
provas = ["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_REDACAO"]
provas.append("NU_NOTA_TOTAL")
dados[provas].query("NU_NOTA_TOTAL == 0")
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# 10             NaN         NaN  ...              NaN            0.0
# 11             NaN         NaN  ...              NaN            0.0
# 26             NaN         NaN  ...              NaN            0.0
# 38             NaN         NaN  ...              NaN            0.0
# 40             NaN         NaN  ...              NaN            0.0
# ...            ...         ...  ...              ...            ...
# 127351         NaN         NaN  ...              NaN            0.0
# 127365         NaN         NaN  ...              NaN            0.0
# 127366         NaN         NaN  ...              NaN            0.0
# 127368         NaN         NaN  ...              NaN            0.0
# 127374         NaN         NaN  ...              NaN            0.0
#
# [29162 rows x 6 columns]

# %%
# excluindo os candidatos que tiraram zero em todas as provas (provavelmente não compareceram)

dados_sem_nota_zero = dados.query("NU_NOTA_TOTAL != 0")
dados_sem_nota_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
plt.figure(figsize=(9,7))
sns.boxplot(x="Q006", y="NU_NOTA_TOTAL", data = dados_sem_nota_zero, order = renda_ordenada)
plt.title("Boxplot do somatório das notas pela renda - excluindo zero total")
# Out:
# Text(0.5, 1.0, 'Boxplot do somatório das notas pela renda - excluindo zero total')

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x="Q006", y="NU_NOTA_TOTAL", data = dados_sem_nota_zero,
            hue = "IN_TREINEIRO", order = renda_ordenada)
plt.title("Boxplot do somatório das notas pela renda - excluindo zero total")
# Out:
# Text(0.5, 1.0, 'Boxplot do somatório das notas pela renda - excluindo zero total')

# %% [markdown]
# Desafio: Amostra de alunos menores de idade e sua proporção por Estados

# %%
dados.query("NU_IDADE < 18")['SG_UF_RESIDENCIA'].value_counts(normalize=True).sort_values(ascending=False).head()
# Out:
# SP    0.234347
# MG    0.100704
# BA    0.063796
# CE    0.062516
# PE    0.057778
# Name: SG_UF_RESIDENCIA, dtype: float64

# %% [markdown]
# Desafio: Criar uma função para plotar o boxplot do seaborn

# %%
def plot_box(y):
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='Q006', y=y, data=dados, order=renda_ordenada)

# %%
plot_box(y="NU_NOTA_MT")
plt.title("Notas de matemática por renda")
# Out:
# Text(0.5, 1.0, 'Notas de matemática por renda')

# %% [markdown]
# Desafio: Verificar se quem zerou a prova foi eliminado ou não estava presente

# %%
# Total que tirou zero

len(dados.query('NU_NOTA_TOTAL == 0'))
# Out:
# 29162

# %%
# ausente em alguma prova

len(dados.query('NU_NOTA_TOTAL == 0').query('TP_PRESENCA_CN == 0 or TP_PRESENCA_CH == 0 or TP_PRESENCA_LC == 0 or TP_PRESENCA_MT == 0'))
# Out:
# 29160

# %%
# eliminado em alguma prova

len(dados.query('NU_NOTA_TOTAL == 0').query('TP_PRESENCA_CN == 2 or TP_PRESENCA_CH == 2 or TP_PRESENCA_LC == 2 or TP_PRESENCA_MT == 2'))
# Out:
# 120

# %% [markdown]
# Desafio: Verificar a proporção dos participantes de rendas mais altas e mais baixas como treineiro e não treineiro.

# %%
dados_nao_treineiros = dados.query('IN_TREINEIRO == 0')['Q006'].value_counts(normalize=True)
dados_sim_treineiros = dados.query('IN_TREINEIRO == 1')['Q006'].value_counts(normalize=True)

df = pd.DataFrame({'Treineiros': dados_nao_treineiros,
                   'Não Treineiros': dados_sim_treineiros})

df.plot.bar(figsize=(10,8))

# %% [markdown]
# Desafio: Fazer o mesmo boxplot olhando para a questão 25 (tem internet ou não)

# %%
plt.figure(figsize=(15,8))
plt.title("Nota TOTAL pela Renda & Internet")
sns.boxplot(x="Q025", y="NU_NOTA_TOTAL", data=dados_sem_nota_zero)

# Não possui acesso a internet (A)
# Possui acesso a internet (B)

# %% [markdown]
# # Aula 03 - Distribuições e correlações entre notas

# %%
plt.figure(figsize=(12,9))
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_TOTAL")
plt.title("Notas totais")
# Out:
# Text(0.5, 1.0, 'Notas totais')

# %%
plt.figure(figsize=(12,9))
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_MT")
plt.title("Notas de matemática")
# Out:
# Text(0.5, 1.0, 'Notas de matemática')

# %%
# Comparação das notas totais de inscritos em relação a declaração de terem ou não internet em casa (coluna Q025)
# kde=True traça uma linha contornando o gráfico para uma melhor visualização

plt.figure(figsize=(12,9))
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True)
plt.title("Notas totais em relação a quem tem ou não internet em casa")

# B = Tem internet em casa
# A = Nao tem internet em casa
# Out:
# Text(0.5, 1.0, 'Notas totais em relação a quem tem ou não internet em casa')

# %%
plt.figure(figsize=(12,9))
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="probability")
plt.title("Notas totais em relação a quem tem ou não internet em casa")
# Out:
# Text(0.5, 1.0, 'Notas totais em relação a quem tem ou não internet em casa')

# %%
plt.figure(figsize=(12,9))
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="probability", cumulative=True)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data = dados_sem_nota_zero, x = "NU_NOTA_MT", y = "NU_NOTA_LC")
plt.xlim((-50,1050))
plt.ylim((-50,1050))
# Out:
# (-50.0, 1050.0)

# %%
sns.pairplot(dados_sem_nota_zero[provas])

# %%
correlacao = dados_sem_nota_zero[provas].corr()
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# NU_NOTA_CN         1.000000    0.668979  ...         0.504740       0.785600
# NU_NOTA_CH         0.668979    1.000000  ...         0.528338       0.735534
# NU_NOTA_MT         0.649527    0.610332  ...         0.493046       0.790051
# NU_NOTA_LC         0.641624    0.744170  ...         0.535797       0.711686
# NU_NOTA_REDACAO    0.504740    0.528338  ...         1.000000       0.783647
# NU_NOTA_TOTAL      0.785600    0.735534  ...         0.783647       1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(correlacao, cmap="Blues", center=0, annot=True)

# %% [markdown]
# # Desafios da aula 03

# %% [markdown]
# Desafio: Plotar as médias, medianas e moda nas notas de LC e MT (matiplotlib linha vertical)

# %%
plt.figure(figsize=(12,8))
media = dados_sem_nota_zero['NU_NOTA_MT'].mean()
moda = dados_sem_nota_zero['NU_NOTA_MT'].mode()[0]
mediana = dados_sem_nota_zero['NU_NOTA_MT'].median()
ax = sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_MT")
plt.axvline(media, c='r') 
plt.axvline(moda, c='g') 
plt.axvline(mediana, c='b') 
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(12,8))
media = dados_sem_nota_zero['NU_NOTA_LC'].mean()
moda = dados_sem_nota_zero['NU_NOTA_LC'].mode()[0]
mediana = dados_sem_nota_zero['NU_NOTA_LC'].median()
ax = sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_LC")
plt.axvline(media, c='r') 
plt.axvline(moda, c='g') 
plt.axvline(mediana, c='b') 
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Desafio 2: Melhorar a visualização da matriz de correlação e analisar mais detalhadamente.

# %%
import numpy as np
mask = np.zeros_like(correlacao)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(correlacao, cmap="Blues", center=0, annot=True, mask=mask)

# %% [markdown]
# Desafio 3: Filtrar as notas por seu estado ou sua cidade e refazer as análises, verificando se são semelhantes ao geral.

# %%
dados_sem_nota_zero_rj = dados_sem_nota_zero.query('SG_UF_RESIDENCIA == "RJ"')
dados_sem_nota_zero_rj.head()
# Out:
#        NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 8210   190001327579    2019                  3301207  ...    B     B        3718.9
# 11354  190001456489    2019                  3304557  ...    B     B        2690.8
# 12837  190001513391    2019                  3304557  ...    B     B        2571.8
# 12840  190001513783    2019                  3304557  ...    B     B        3035.4
# 12842  190001513830    2019                  3304557  ...    B     B        3746.3
#
# [5 rows x 137 columns]

# %% [markdown]
# # Aula 04 - Modelo de Machine Learning

# %%
provas_entrada = ["NU_NOTA_CH", "NU_NOTA_LC", "NU_NOTA_CN", "NU_NOTA_REDACAO"]
prova_saida = "NU_NOTA_MT"

# É preciso remover os dados 'NaN' das provas para alguns modelos de machine learning (atualizando a variável)
dados_sem_nota_zero = dados_sem_nota_zero[provas].dropna()

notas_entrada = dados_sem_nota_zero[provas_entrada]
notas_saida = dados_sem_nota_zero[prova_saida]

# %%
notas_entrada
# Out:
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_CN  NU_NOTA_REDACAO
# 0            512.3       488.6       435.6            420.0
# 2            499.1       441.0       423.2            560.0
# 3            578.1       551.5       426.2            500.0
# 4            571.3       511.2       516.5            780.0
# 5            618.7       607.5       559.6            900.0
# ...            ...         ...         ...              ...
# 127373       501.5       485.3       480.4            520.0
# 127375       559.6       525.7       502.4            740.0
# 127376       380.9       450.3       449.1            520.0
# 127378       416.2       517.3       564.7            620.0
# 127379       425.5       477.1       466.7            480.0
#
# [92537 rows x 4 columns]

# %%
# f(x) = y

x = notas_entrada
y = notas_saida

# %%
from sklearn.model_selection import train_test_split

# variável com um número qualquer para que os treinos e testes não sejam aleatórios, mas sim iguais
SEED = 4321

x_treino, x_teste, y_treino, y_teste, = train_test_split(x, y, test_size= 0.25, random_state = SEED)

# %%
x_treino.head()
# Out:
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_CN  NU_NOTA_REDACAO
# 90200        567.7       523.2       542.7            660.0
# 12375        497.1       423.0       445.2            580.0
# 46320        494.0       528.5       454.0            520.0
# 111208       561.9       572.7       385.8            640.0
# 75943        686.5       646.5       625.7            900.0

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state = SEED)
modelo.fit(x_treino, y_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=4321, tol=0.0001, verbose=0)

# %%
# predição das notas

predicoes_matematica = modelo.predict(x_teste)

# %%
predicoes_matematica
# Out:
# array([564.48610537, 628.305027  , 509.98098555, ..., 607.78717234,
#        734.22766309, 466.91968988])

# %%
# comparação da predição com os valores reais

y_teste[:5]
# Out:
# 114991    459.7
# 104685    617.2
# 91028     520.0
# 115802    703.8
# 93303     627.1
# Name: NU_NOTA_MT, dtype: float64

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=predicoes_matematica, y=y_teste)
plt.xlim(-50, 1050)
plt.ylim(-50, 1050)
# Out:
# (-50.0, 1050.0)

# %%
# diferença entre as notas reais (x) e previsão (y - erro) - margem de erro

plt.figure(figsize=(8,8))
sns.scatterplot(x=y_teste, y=y_teste - predicoes_matematica)
plt.xlim(-50, 1050)
plt.ylim(-50, 1050)
# Out:
# (-50.0, 1050.0)

# %%
resultados = pd.DataFrame()
resultados["Real"] = y_teste
resultados["Previsao"] = predicoes_matematica
resultados["Diferenca"] = resultados["Real"] - resultados["Previsao"]
resultados["Quadrado_Diferenca"] = (resultados["Real"] - resultados["Previsao"])**2

# %%
resultados
# Out:
#          Real    Previsao   Diferenca  Quadrado_Diferenca
# 114991  459.7  564.486105 -104.786105        10980.127878
# 104685  617.2  628.305027  -11.105027          123.321625
# 91028   520.0  509.980986   10.019014          100.380650
# 115802  703.8  593.681144  110.118856        12126.162420
# 93303   627.1  579.784588   47.315412         2238.748252
# ...       ...         ...         ...                 ...
# 81393   688.6  626.291851   62.308149         3882.305380
# 40159   479.1  652.313922 -173.213922        30003.062777
# 64083   501.4  607.787172 -106.387172        11318.230438
# 84661   772.5  734.227663   38.272337         1464.771772
# 79106   369.0  466.919690  -97.919690         9588.265665
#
# [23135 rows x 4 columns]

# %%
resultados["Quadrado_Diferenca"].mean()**(1/2)
# Out:
# 81.26755383435341

# %%
from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor()
modelo_dummy.fit(x_treino, y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12063.645588509502

# %%
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# 6604.41530621957

# %% [markdown]
# # Desafios da aula 04

# %%
# Desafio 1 - Procurar outro modelo de ML para treinar e comparar com os modelos criados em aula

from sklearn.tree import DecisionTreeRegressor

modelo = DecisionTreeRegressor(random_state=SEED)
modelo.fit(x_treino, y_treino)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=4321, splitter='best')

# %% [markdown]
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm

# %%
predicoes_matematica = modelo.predict(x_teste)

mean_squared_error(y_teste, predicoes_matematica)
# Out:
# 11377.563438080831

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x=predicoes_matematica, y=y_teste)
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
from sklearn.svm import SVR

modelo = SVR(C=1.0, epsilon=0.2)
modelo.fit(x_treino, y_treino)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
predicoes_matematica = modelo.predict(x_teste)

mean_squared_error(y_teste, predicoes_matematica)
# Out:
# 5476.448428934274

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x=predicoes_matematica, y=y_teste)
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
# Desafio 2 - Ler a documentação do Dummy e alterar o método de regressão

from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor(strategy='quantile', quantile=.65)
modelo_dummy.fit(x_treino, y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html#sklearn.dummy.DummyRegressor

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12982.67123276421

# %%
# Desafio 3 - Buscar outra métrica para avaliar modelos de regressão

from sklearn.metrics import r2_score

r2_score(y_teste, dummy_predicoes)
# Out:
# -0.07635934330569105

# %% [markdown]
# https://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics

# %%
from sklearn.metrics import r2_score

r2_score(y_teste, predicoes_matematica)
# Out:
# 0.3615928262721678

# %% [markdown]
# # Aula 05 - Validação de modelo e Overfit

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR()
modelo.fit(x_treino, y_treino)
predicoes_matematica = modelo.predict(x_teste)
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 7700.2448120086

# %%
# Novo modelo de machine learning

from sklearn.tree import DecisionTreeRegressor

modelo_arvore = DecisionTreeRegressor(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
predicoes_matematica_arvore = modelo_arvore.predict(x_teste)

# %%
mean_squared_error(y_teste, predicoes_matematica_arvore)
# Out:
# 6027.166905272976

# %%
# Modelo de cross validation

from sklearn.model_selection import cross_validate

modelo_arvore = DecisionTreeRegressor(max_depth= 2)
resultados = cross_validate(modelo_arvore, x, y, cv= 10, scoring="neg_mean_squared_error")
media = (resultados["test_score"]*-1).mean()
desvio_padrao = (resultados["test_score"]*-1).std()
lim_inferior = media - (2*desvio_padrao)
lim_superior = media + (2*desvio_padrao)

print(f"Intervalo de confiança {lim_inferior} - {lim_superior}")
# Out:
# Intervalo de confiança 6015.722549536806 - 7100.73277978073

# %%
media
# Out:
# 6558.227664658768

# %%
resultados["test_score"]*-1
# Out:
# array([6118.6911947 , 6536.09830186, 6338.64260896, 6456.70685686,
#        6234.97203593, 6794.25120283, 6713.45694262, 6693.04880297,
#        6610.58461646, 7085.82408339])

# %%
# criando uma função

def calcula_mse(resultados):

  media = (resultados["test_score"]*-1).mean()
  desvio_padrao = (resultados["test_score"]*-1).std()
  lim_inferior = media - (2*desvio_padrao)
  lim_superior = media + (2*desvio_padrao)
  print(f"Intervalo de confiança {lim_inferior} - {lim_superior}")

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
# Faz com que os resultados não sejam randômicos para efeito de teste

# ---

partes = KFold(n_splits = 10, shuffle=True)
modelo_arvore = DecisionTreeRegressor(max_depth=2)
resultados = cross_validate(modelo_arvore, x, y, cv=partes, scoring="neg_mean_squared_error")
calcula_mse(resultados)
# Out:
# Intervalo de confiança 6398.74565606743 - 6716.084123120491

# %%
def regressor_arvore(nivel):
    SEED= 1232
    np.random.seed(SEED)
    partes = KFold(n_splits = 10, shuffle=True)
    modelo_arvore = DecisionTreeRegressor(max_depth=nivel)
    resultados = cross_validate(modelo_arvore, x, y, cv= partes, scoring="neg_mean_squared_error", return_train_score=True)
    print(f"Treino = {(resultados['train_score']*-1).mean()}|Teste = {(resultados['test_score']*-1).mean()}")

regressor_arvore(4)
# Out:
# Treino = 5760.834451245899|Teste = 5815.707286597402

# %%
for i in range(1,21):
    regressor_arvore(i)
# Out:
# Treino = 7844.952652412207|Teste = 7857.871770206351
# Treino = 6527.783475408351|Teste = 6556.886287657656
# Treino = 6021.275229419075|Teste = 6054.767567442072
# Treino = 5760.834451245899|Teste = 5815.707286597402
# Treino = 5598.158955426787|Teste = 5675.196789060744
# Treino = 5469.677369145869|Teste = 5593.304363812442
# Treino = 5369.458309852721|Teste = 5541.646599457925
# Treino = 5276.16965707928|Teste = 5542.053091078966
# Treino = 5166.713159932668|Teste = 5608.390265709719
# Treino = 5022.598049115693|Teste = 5761.4934268457555
# Treino = 4833.560706021637|Teste = 5955.331403579403
# Treino = 4598.125022484774|Teste = 6217.553668629227
# Treino = 4316.3791662866815|Teste = 6521.403312280134
# Treino = 4000.6209880837496|Teste = 6853.984106997142
# Treino = 3655.8197526274853|Teste = 7224.863053512405
# Treino = 3295.832684540846|Teste = 7636.168819779455
# Treino = 2931.7212612043877|Teste = 8071.851486256819
# Treino = 2575.59534021339|Teste = 8452.126711298857
# ...
